# %% [markdown]
# # Assignment 5
# **Name: Sushrut Gaikwad**

# %% [markdown]
# ## Question 1
# Convert 1D array Into 2D array. You are given a `0`-indexed 1-dimensional (1D) integer array `original`, and two integers, `m` and `n`. You are tasked with creating a 2-dimensional (2D) array with `m` rows and `n` columns using all the elements from `original`. The elements from indices `0` to `n - 1` (inclusive) of `original` should form the first row of the constructed 2D array, the elements from indices `n` to `2 * n - 1` (inclusive) should form the second row of the constructed 2D array, and so on. Return an `m × n` 2D array constructed according to the above procedure, or an empty 2D array if it is impossible.
#
# **Example:**
#
# ![Ass_5_q1.png](attachment:Ass_5_q1.png)
#
# Input: `original = [1, 2, 3, 4]`, `m = 2`, `n = 2`.
#
# Output: `[[1, 2], [3, 4]]`.
#
# Explanation: The constructed 2D array should contain `2` rows and `2` columns. The first group of `n = 2` elements in original, `[1, 2]`, becomes the first row in the constructed 2D array. The second group of `n = 2` elements in original, `[3, 4]`, becomes the second row in the constructed 2D array.

# %% [markdown]
# **Answer:**

# %%
def one_d_to_two_d(original: list, m: int, n: int):
    if m * n != len(original):
        return [[]]
    else:
        arr = ([[0]*n]*m)
        
        i = 0
        j = 0
        for r in range(m):
            arr[j] = original[i:i+2]
            j += 1
            i += 2
        return arr

# %%
original = [1, 2, 3, 4]
m = 2
n = 2

one_d_to_two_d(original, m, n)
# Out:
# [[1, 2], [3, 4]]

# %%
original = [1, 2, 3, 4, 5, 6]
m = 3
n = 2

one_d_to_two_d(original, m, n)
# Out:
# [[1, 2], [3, 4], [5, 6]]

# %%
original = [1, 2, 3, 4, 5, 6, 7]
m = 3
n = 3

one_d_to_two_d(original, m, n)
# Out:
# [[]]

# %% [markdown]
# ## Question 2
# You have `n` coins and you want to build a staircase with these coins. The staircase consists of `k` rows where the `i`-th row has exactly `i` coins. The last row of the staircase may be incomplete. Given the integer `n`, return the number of complete rows of the staircase you will build.
#
# **Example:**
#
# ![Ass4_q5.png](attachment:Ass4_q5.png)
#
# Input: `n = 5`.
#
# Output: `2`.
#
# Explanation: Because the 3rd row is incomplete, we return `2`.

# %% [markdown]
# **Answer:**

# %%
def number_of_complete_rows_of_the_coin_staircase(n: int):
    k_list = []
    for i in range(1, n + 1):
        for j in range(1, i + 1):
            k_list.append(i)

    k = k_list[:n][-1]
    
    total_spots = (k*(k + 1)) // 2
    
    if n == total_spots:
        return k
    else:
        return k - 1

# %%
n = 5

number_of_complete_rows_of_the_coin_staircase(n)
# Out:
# 2

# %%
n = 11

number_of_complete_rows_of_the_coin_staircase(n)
# Out:
# 4

# %% [markdown]
# ## Question 3
# Given an integer array `nums` sorted in non-decreasing order, return an array of the squares of each number sorted in non-decreasing order.
#
# **Example:**
#
# Input: `nums = [-4, -1, 0, 3, 10]`.
#
# Output: `[0, 1, 9, 16, 100]`.
#
# Explanation: After squaring, the array becomes `[16, 1, 0, 9, 100]`.
#
# After sorting, it becomes `[0, 1, 9, 16, 100]`.

# %% [markdown]
# **Answer:**

# %%
def square_sort(nums: list):
    for i in range(len(nums)):
        nums[i] = nums[i] * nums[i]
    nums.sort()
    return nums

# %%
nums = [-4, -1, 0, 3, 10]
square_sort(nums)
# Out:
# [0, 1, 9, 16, 100]

# %% [markdown]
# ## Question 4
# Given two `0`-indexed integer arrays `nums1` and `nums2`, return a list `answer` of size `2` where:
# * `answer[0]` is a list of all distinct integers in `nums1` which are not present in `nums2`.
# * `answer[1]` is a list of all distinct integers in `nums2` which are not present in `nums1`.
#
# Note that the integers in the lists may be returned in any order.
#
# **Example:**
#
# Input: `nums1 = [1, 2, 3]`, `nums2 = [2, 4, 6]`.
#
# Output: `[[1, 3], [4, 6]]`
#
# Explanation:
# * For `nums1`, `nums1[1] = 2` is present at index `0` of `nums2`, whereas `nums1[0] = 1` and `nums1[2] = 3` are not present in `nums2`. Therefore, `answer[0] = [1, 3]`.
# * For `nums2`, `nums2[0] = 2` is present at index `1` of `nums1`, whereas `nums2[1] = 4` and `nums2[2] = 6` are not present in `nums2`. Therefore, `answer[1] = [4, 6]`.

# %% [markdown]
# **Answer:**

# %%
def question_4(nums1: list, nums2: list):
    answer = []

    nums1_minus_nums2 = []

    for i in nums1:
        if i not in nums2:
            nums1_minus_nums2.append(i)

    nums2_minus_nums1 = []

    for i in nums2:
        if i not in nums1:
            nums2_minus_nums1.append(i)

    answer.append(nums1_minus_nums2)
    answer.append(nums2_minus_nums1)
    
    return answer

# %%
nums1 = [1, 2, 3]
nums2 = [2, 4, 6]

question_4(nums1, nums2)
# Out:
# [[1, 3], [4, 6]]

# %% [markdown]
# ## Question 5
# Given two integer arrays `arr1` and `arr2`, and the integer `d`, return the distance value between the two arrays. The distance value is defined as the number of elements `arr1[i]` such that there is not any element `arr2[j]` where `|arr1[i]-arr2[j]| <= d`.
#
# **Example:**
#
# Input: `arr1 = [4, 5, 8]`, `arr2 = [10, 9, 1, 8]`, `d = 2`.
#
# Output: `2`.
#
# Explanation:
#
# For `arr1[0] = 4` we have:
#
# `|4-10|=6 > d=2`
#
# `|4-9|=5 > d=2`
#
# `|4-1|=3 > d=2`
#
# `|4-8|=4 > d=2`
#
# For `arr1[1] = 5` we have:
#
# `|5-10|=5 > d=2`
#
# `|5-9|=4 > d=2`
#
# `|5-1|=4 > d=2`
#
# `|5-8|=3 > d=2`
#
# For `arr1[2] = 8` we have:
#
# `|8-10|=2 <= d=2`
#
# `|8-9|=1 <= d=2`
#
# `|8-1|=7 > d=2`
#
# `|8-8|=0 <= d=2`

# %% [markdown]
# **Answer:**

# %%
def distance_between_two_arrays(arr1: list, arr2: list, d: int):
    good_numbers_index = [1] * len(arr1)

    for i in range(len(arr1)):
        for num2 in arr2:
            if abs(arr1[i] - num2) <= d:
                good_numbers_index[i] = 0

    count = 0
    for i in good_numbers_index:
        if i == 1:
            count += 1
    
    return count

# %%
arr1 = [4, 5, 8]
arr2 = [10, 9, 1, 8]
d = 2

distance_between_two_arrays(arr1, arr2, d)
# Out:
# 2

# %%
arr1 = [1, 4, 2, 3]
arr2 = [-4, -3, 6, 10, 20, 30]
d = 3

distance_between_two_arrays(arr1, arr2, d)
# Out:
# 2

# %%
arr1 = [2, 1, 100, 3]
arr2 = [-5, -2, 10, -3, 7]
d = 6

distance_between_two_arrays(arr1, arr2, d)
# Out:
# 1

# %% [markdown]
# ## Question 6
# Given an integer array `nums` of length `n` where all the integers of nums are in the range `[1, n]` and each integer appears once or twice, return an array of all the integers that appears twice. You must write an algorithm that runs in $\mathcal{O}\left( n \right)$ time and uses only constant extra space.
#
# **Example:**
#
# Input: `nums = [4, 3, 2, 7, 8, 2, 3, 1]`.
#
# Output: `[2, 3]`.

# %% [markdown]
# **Answer:**

# %%
def duplicates(nums: list):
    
    dup_list = []
    
    for num in nums:
        if nums[abs(num) - 1] > 0:
            nums[abs(num) - 1] = -nums[abs(num) - 1]
        else:
            dup_list.append(abs(num))
    
    return dup_list

# %%
nums = [4, 3, 2, 7, 8, 2, 3, 1]

duplicates(nums)
# Out:
# [2, 3]

# %%
nums = [1, 1, 2, 3, 4, 4, 5, 6, 7, 7]

duplicates(nums)
# Out:
# [1, 4, 7]

# %% [markdown]
# ## Question 7
# Suppose an array of length `n` sorted in ascending order is rotated between `1` and `n` times. For example, the array `nums = [0, 1, 2, 4, 5, 6, 7]` might become:
# * `[4, 5, 6, 7, 0, 1, 2]` if it was rotated `4` times.
# * `[0, 1, 2, 4, 5, 6, 7]` if it was rotated `7` times.
#
# Notice that rotating an array `[a[0], a[1], a[2], ..., a[n-1]]` `1` time results in the array `[a[n-1], a[0], a[1], a[2], ..., a[n-2]]`. Given the sorted rotated array `nums` of unique elements, return the minimum element of this array. You must write an algorithm that runs in $\mathcal{O}\left( \log n \right)$ time.
#
# **Example:**
#
# Input: `nums = [3, 4, 5, 1, 2]`.
#
# Output: `1`.
#
# Explanation: The original array was `[1, 2, 3, 4, 5]` rotated `3` times.

# %% [markdown]
# **Answer:**

# %%
def min_element(nums: list):
    lo = 0
    hi = len(nums) - 1
    
    while lo < hi:
        mid = (lo + hi) // 2
        
        if nums[mid] > nums[hi]:
            lo = mid + 1
        else:
            hi = mid
    
    return nums[lo]

# %%
nums = [3, 4, 5, 1, 2]

min_element(nums)
# Out:
# 1

# %%
nums = [3, 4, 5, 1, 2]

min_element(nums)

# %%
nums = [4, 5, 6, 7, 0, 1, 2]

min_element(nums)
# Out:
# 0

# %%
nums = [11, 13, 15, 17]

min_element(nums)
# Out:
# 11

# %% [markdown]
# ## Question 8
# An integer array `original` is transformed into a doubled array changed by appending twice the value of every element in `original`, and then randomly shuffling the resulting array. Given an array `changed`, return `original` if `changed` is a doubled array. If `changed` is not a doubled array, return an empty array. The elements in `original` may be returned in any order.
#
# **Example:**
#
# Input: `changed = [1, 3, 4, 2, 6, 8]`.
#
# Output: `[1, 3, 4]`.
#
# Explanation: One possible `original` array could be `[1, 3, 4]`:
# * Twice the value of `1` is `1 * 2 = 2`.
# * Twice the value of `3` is `3 * 2 = 6`.
# * Twice the value of `4` is `4 * 2 = 8`.
#
# Other `original` arrays could be `[4, 3, 1]` or `[3, 1, 4]`.

# %% [markdown]
# **Answer:**
